# %%
from sklearn.preprocessing import MultiLabelBinarizer
import pandas as pd

# Reading data from a CSV file
data = pd.read_csv('../data.csv')

data["popularity"] = data["popularity"].apply(lambda pop: pop/100)
data["tempo"] = data["tempo"].apply(lambda tpo: tpo/100)
data["loudness"] = data["loudness"].apply(lambda ldn: ldn/40)
data["popularity"] = data["popularity"].fillna(data["popularity"].median())
data["genres"] = data["genres"].fillna("")
data["genres"] = data["genres"].str.split(".")

df = pd.DataFrame(data)[:-10]

df = df.drop(columns=['songname','artist', 'id'])

# Define input features and target variables
features = df[['time', 'dayofweek', 'month', 'temp']]
targets = df.drop(columns=['time', 'dayofweek', 'month', 'temp', 'genres'])

classifier_target = df['genres']

mlb = MultiLabelBinarizer()
classifier_target = mlb.fit_transform(classifier_target)

# %%
from sklearn.preprocessing import LabelEncoder
from src.python_files.num_predict import train_gradient_boosting_regressor
from src.python_files.cat_predict import train_random_forest_classifier

model = train_random_forest_classifier(features, classifier_target)[0]

genres_arr = []
for item in df['genres']:
    genres_arr.append(item[0])
le = LabelEncoder()
genres_encoded = le.fit_transform(genres_arr)
features.insert(4, 'genres', genres_encoded)

multi_output_gbr = train_gradient_boosting_regressor(features, targets)[0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 from src.python_files.num_predict import train_gradient_boosting_regressor
#       3 from src.python_files.cat_predict import train_random_forest_classifier
# ----> 5 model = train_random_forest_classifier(features, classifier_target)[0]
#       7 genres_arr = []
#       8 for item in df['genres']:
#
# File ~/Downloads/Project01_ML/src/python_files/cat_predict.py:27, in train_random_forest_classifier(features, target)
#      24 x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)
#      26 # Train the model
# ---> 27 model.fit(x_train, y_train)
#      29 return model, x_test, y_test
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/pipeline.py:473, in Pipeline.fit(self, X, y, **params)
#     471     if self._final_estimator != "passthrough":
#     472         last_step_params = routed_params[self.steps[-1][0]]
# --> 473         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     475 return self
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/multioutput.py:543, in MultiOutputClassifier.fit(self, X, Y, sample_weight, **fit_params)
#     517 def fit(self, X, Y, sample_weight=None, **fit_params):
#     518     """Fit the model to data matrix X and targets Y.
#     519
#     520     Parameters
#    (...)
#     541         Returns a fitted instance.
#     542     """
# --> 543     super().fit(X, Y, sample_weight=sample_weight, **fit_params)
#     544     self.classes_ = [estimator.classes_ for estimator in self.estimators_]
#     545     return self
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/multioutput.py:278, in _MultiOutputEstimator.fit(self, X, y, sample_weight, **fit_params)
#     275     if sample_weight is not None:
#     276         routed_params.estimator.fit["sample_weight"] = sample_weight
# --> 278 self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#     279     delayed(_fit_estimator)(
#     280         self.estimator, X, y[:, i], **routed_params.estimator.fit
#     281     )
#     282     for i in range(y.shape[1])
#     283 )
#     285 if hasattr(self.estimators_[0], "n_features_in_"):
#     286     self.n_features_in_ = self.estimators_[0].n_features_in_
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/multioutput.py:67, in _fit_estimator(estimator, X, y, sample_weight, **fit_params)
#      65     estimator.fit(X, y, sample_weight=sample_weight, **fit_params)
#      66 else:
# ---> 67     estimator.fit(X, y, **fit_params)
#      68 return estimator
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
#     479     self._make_estimator(append=False, random_state=random_state)
#     480     for i in range(n_more_estimators)
#     481 ]
#     483 # Parallel loop: we prefer the threading backend as the Cython code
#     484 # for fitting the trees is internally releasing the Python GIL
#     485 # making threading more efficient than multiprocessing in
#     486 # that case. However, for joblib 0.12+ we respect any
#     487 # parallel_backend contexts set at a higher level,
#     488 # since correctness does not rely on using threads.
# --> 489 trees = Parallel(
#     490     n_jobs=self.n_jobs,
#     491     verbose=self.verbose,
#     492     prefer="threads",
#     493 )(
#     494     delayed(_parallel_build_trees)(
#     495         t,
#     496         self.bootstrap,
#     497         X,
#     498         y,
#     499         sample_weight,
#     500         i,
#     501         len(trees),
#     502         verbose=self.verbose,
#     503         class_weight=self.class_weight,
#     504         n_samples_bootstrap=n_samples_bootstrap,
#     505         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     506     )
#     507     for i, t in enumerate(trees)
#     508 )
#     510 # Collect newly grown trees
#     511 self.estimators_.extend(trees)
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:179, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     176 else:
#     177     curr_sample_weight = sample_weight.copy()
# --> 179 indices = _generate_sample_indices(
#     180     tree.random_state, n_samples, n_samples_bootstrap
#     181 )
#     182 sample_counts = np.bincount(indices, minlength=n_samples)
#     183 curr_sample_weight *= sample_counts
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:132, in _generate_sample_indices(random_state, n_samples, n_samples_bootstrap)
#     128 def _generate_sample_indices(random_state, n_samples, n_samples_bootstrap):
#     129     """
#     130     Private function used to _parallel_build_trees function."""
# --> 132     random_instance = check_random_state(random_state)
#     133     sample_indices = random_instance.randint(
#     134         0, n_samples, n_samples_bootstrap, dtype=np.int32
#     135     )
#     137     return sample_indices
#
# File ~/Downloads/Project01_ML/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:1436, in check_random_state(seed)
#    1434     return np.random.mtrand._rand
#    1435 if isinstance(seed, numbers.Integral):
# -> 1436     return np.random.RandomState(seed)
#    1437 if isinstance(seed, np.random.RandomState):
#    1438     return seed
#
# File numpy/random/mtrand.pyx:184, in numpy.random.mtrand.RandomState.__init__()
#
# File _mt19937.pyx:132, in numpy.random._mt19937.MT19937.__init__()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# KeyboardInterrupt:

# %%
from src.python_files.record import get_weather_info, get_hour_info, get_weekday_info, get_month_info
import nest_asyncio
import asyncio

nest_asyncio.apply()

temp = float(asyncio.run(get_weather_info()))
time = float(get_hour_info())
day = float(get_weekday_info())
month = float(get_month_info())

# %%
from rapidfuzz import fuzz

# time, dow, month, temp
cat_predict_value = pd.DataFrame([[time, day, month, temp]], columns=["time", "dayofweek", "month", "temp"])

class_predict = model.predict(cat_predict_value)

print(mlb.classes_)

probabilities = model.predict_proba(cat_predict_value)

top_probs_idx = []
# idx, value
top_prob = [0, 0]

for prob_idx in range(len(probabilities)):
    if len(probabilities[prob_idx][0]) == 2 and probabilities[prob_idx][0][1] > .1:
        top_probs_idx.append(prob_idx)
        if top_prob[1] < probabilities[prob_idx][0][1] and mlb.classes_[prob_idx] != "":
            top_prob[1] = probabilities[prob_idx][0][1]
            top_prob[0] = prob_idx
            
comparison_cats = []

for idx in top_probs_idx:
    if mlb.classes_[idx] == "":
        continue
    print(mlb.classes_[idx])
    print(fuzz.token_set_ratio(mlb.classes_[top_prob[0]], mlb.classes_[idx]))
    if fuzz.token_set_ratio(mlb.classes_[top_prob[0]], mlb.classes_[idx]) >= 40:
        comparison_cats.append(mlb.classes_[idx])

num_predict_cats = le.transform([comparison_cats[0]])
    
num_predict_value = pd.DataFrame([[time, day, month, temp, num_predict_cats]], columns=["time", "dayofweek", "month", "temp", "genres"])    

# Make predictions
y_pred = multi_output_gbr.predict(num_predict_value)
 
print(comparison_cats)
# print(y_pred)
# print((df.drop(columns=['time', 'dayofweek', 'month', 'temp', 'genres'])).keys())
# Out:
# ['' ' ' ' afro r&b' ' afrofuturism' ' aggressive phonk' ' alaska indie'
#  ' album rock' ' alt z' ' alternative country' ' alternative dance'
#  ' alternative pop rock' ' alternative r&b' ' ambient folk'
#  ' ambient lo-fi' ' art pop' ' asbury park indie'
#  ' asian american hip hop' ' atl hip hop' ' atlanta indie'
#  ' aussietronica' ' australian hip hop' ' australian indie folk'
#  ' australian psych' ' baroque pop' ' bedroom pop' ' bedroom r&b'
#  ' boy band' ' british invasion' ' bronx drill' ' brooklyn indie'
#  ' canadian contemporary r&b' ' canadian hip hop' ' chamber pop'
#  ' chill r&b' ' chillsynth' ' classic oklahoma country' ' classic rock'
#  ' classic soul' ' colombian pop' ' corecore' ' countrygaze' ' dance pop'
#  ' deep new americana' ' denpa-kei' ' disco' ' dreamo' ' drift phonk'
#  ' dutch r&b' ' east coast hip hop' ' edm' ' edmonton indie' ' folk-pop'
#  ' french shoegaze' ' future funk' ' gauze pop' ' hardwave'
#  ' hypnagogic pop' ' indie folk' ' indie garage rock' ' indie hip hop'
#  ' indie pop' ' indie r&b' ' indie soul' ' irish singer-songwriter'
#  ' jam band' ' japanese chillhop' ' lgbtq+ hip hop' ' meme'
#  ' modern alternative pop' ' modern alternative rock' ' modern dream pop'
#  ' modern indie folk' ' modern indie pop' ' new romantic'
#  ' newcastle nsw indie' ' nyc pop' ' pop' ' pop rap' ' pop reggaeton'
#  ' pov: indie' ' r&b' ' rap' ' reggaeton' ' retro soul' ' sad lo-fi'
#  ' singer-songwriter pop' ' uk alternative hip hop' ' uk contemporary r&b'
#  ' vapor soul' ' viral pop' ' weirdcore' '5th wave emo' 'abstract beats'
#  'afro r&b' 'afrobeats' 'afrofuturism' 'afropop' 'aggressive phonk'
#  'alabama indie' 'alabama rap' 'album rock' 'alt z' 'alte'
#  'alternative hip hop' 'alternative pop rock' 'alternative r&b'
#  'alternative rock' 'ambient lo-fi' 'anime phonk' 'art pop'
#  'asbury park indie' 'asian american hip hop' 'atl hip hop' 'atl trap'
#  'atlanta indie' 'aussietronica' 'australian alternative rock'
#  'australian dance' 'australian electropop' 'australian hip hop'
#  'australian indie folk' 'australian indie rock' 'australian pop'
#  'australian psych' 'australian reggae fusion' 'australian rock'
#  'australian surf rock' 'azonto' 'baltimore indie' 'baroque pop'
#  'bass house' 'bedroom pop' 'bedroom r&b' 'bedroom soul' 'bergen indie'
#  'birmingham grime' 'blues rock' 'boston folk' 'boston hip hop'
#  'british blues' 'british invasion' 'brooklyn indie' 'bubblegrunge'
#  'canadian contemporary r&b' 'canadian hip hop' 'canadian modern jazz'
#  'canadian pop' 'canadian trap' 'candy pop' 'chamber pop' 'chicago drill'
#  'chicago indie' 'chicago rap' 'chill abstract hip hop' 'chill dream pop'
#  'chill phonk' 'chill pop' 'chill r&b' 'chillhop' 'chillsynth' 'chillwave'
#  'classic city pop' 'classic japanese jazz' 'classic rock' 'cloud rap'
#  'collage pop' 'colombian pop' 'conscious hip hop' 'contemporary r&b'
#  'corecore' 'country rock' 'countrygaze' 'cyberpunk' 'dance pop'
#  'dance rock' 'dark synthpop' 'dark trap' 'deep new americana'
#  'derry indie' 'detroit hip hop' 'dfw rap' 'digital hardcore' 'disco'
#  'dream pop' 'dreamo' 'drift phonk' 'drill' 'drumless hip hop' 'dutch pop'
#  'east coast hip hop' 'eau claire indie' 'edm' 'edmonton indie'
#  'electric blues' 'electro' 'electronica' 'electropop' 'emoplugg'
#  'escape room' 'etherpop' 'experimental hip hop' 'experimental r&b'
#  'filter house' 'florida drill' 'florida rap' 'focus beats' 'folk'
#  'folk rock' 'folk-pop' 'fremantle indie' 'french pop' 'french synthpop'
#  'funk' 'funk carioca' 'funk pop' 'furry' 'future bass' 'future funk'
#  'gangster rap' 'garage house' 'gen z singer-songwriter'
#  'ghanaian alternative' 'ghanaian pop' 'glam metal' 'glam rock' 'grime'
#  'gym phonk' 'hard rock' 'hardwave' 'hip hop' 'house' 'hypnagogic pop'
#  'indie folk' 'indie garage rock' 'indie hip hop' 'indie pop'
#  'indie poptimism' 'indie r&b' 'indie rock' 'indie soul' 'indie surf'
#  'indietronica' 'indonesian r&b' 'instrumental grime'
#  'instrumental hip hop' 'irish singer-songwriter' 'j-core' 'jam band'
#  'jazz funk' 'jersey club' 'k-pop girl group' 'k-rap' 'kawaii future bass'
#  'kiwi rock' 'la indie' 'la pop' 'lgbtq+ hip hop' 'liverpool indie'
#  'lo-fi beats' 'lo-fi chill' 'lo-fi indie' 'lo-fi rap' 'lo-fi vgm'
#  'london rap' 'melancholia' 'mellow gold' 'melodic drill' 'melodic rap'
#  'meme' 'meme rap' 'memphis soul' 'merseybeat' 'metropopolis'
#  'miami hip hop' 'miami indie' 'modern alternative pop'
#  'modern alternative rock' 'modern dream pop' 'modern folk rock'
#  'modern indie pop' 'modern power pop' 'modern rock' 'motown' 'neo mellow'
#  'neo soul' 'neo-psychedelic' 'neo-synthpop' 'new jersey rap' 'new rave'
#  'new romantic' 'new wave' 'new wave pop' 'newcastle nsw indie'
#  'nigerian hip hop' 'nigerian pop' 'noise pop' 'north carolina hip hop'
#  'norwegian indie' 'norwegian pop' 'nu disco' 'nyc pop' 'nz pop'
#  'oakland indie' 'old school bassline' 'p funk' 'permanent wave'
#  'persian electronic' 'perth indie' 'philly indie' 'philly soul'
#  'pittsburgh indie' 'pittsburgh rap' 'pixel' 'pop' 'pop dance' 'pop folk'
#  'pop lgbtq+ brasileira' 'pop nacional' 'pop rap' 'pop rock' 'pop soul'
#  'portland hip hop' 'portland indie' 'post-teen pop' 'pov: indie'
#  'psychedelic hip hop' 'psychedelic pop' 'psychedelic rock'
#  'psychedelic soul' 'quiet storm' 'r&b' 'r&b francais' 'r&drill'
#  'rally house' 'rap' 'reggaeton' 'retro soul' 'rochester mn indie' 'rock'
#  'sad lo-fi' 'san diego indie' 'san marcos tx indie' 'scottish electronic'
#  'seattle indie' 'shimmer pop' 'shiver pop' 'sillycore'
#  'singer-songwriter' 'singer-songwriter pop' 'slacker rock' 'slap house'
#  'slc indie' 'small room' 'social media pop' 'soft rock' 'sophisti-pop'
#  'soul' 'soul blues' 'souldies' 'south african hip hop'
#  'south african trap' 'southern hip hop' 'southern soul' 'spacewave'
#  'sped up' 'stomp and flutter' 'stomp and holler' 'stutter house'
#  'surf punk' 'synthpop' 'synthwave' 'tennessee hip hop' 'toronto indie'
#  'trap' 'trap latino' 'trap soul' 'uk alternative hip hop'
#  'uk contemporary r&b' 'uk dance' 'uk funky' 'uk garage' 'uk hip hop'
#  'uk pop' 'uk post-punk' 'underground hip hop' 'urban contemporary'
#  'urbano latino' 'utopian virtual' 'vapor pop' 'vapor soul' 'vapor twitch'
#  'vaporwave' 'vegas indie' 'vgm remix' 'video game music' 'viral pop'
#  'weirdcore' 'west coast rap' 'west coast reggae' 'wonky' 'yacht rock'
#  'zoomergaze']
# aussietronica
# 27.272727272727266
# bedroom pop
# 50.0
# future funk
# 20.0
# indie pop
# 100.0
# modern rock
# 40.0
# pop
# 100.0
# pov: indie
# 84.21052631578948
# ['bedroom pop', 'indie pop', 'modern rock', 'pop', 'pov: indie']

# %%
dataset = pd.read_csv('../dataset.csv')

predicted_cols=['popularity', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']

ignore_cols = ["duration_ms", "popularity", "loudness"]

prediction_weighting = [
    1, #popularity
    1, #danceability
    1.5, #energy
    0, #loudness
    1, #speechiness
    .9, #acousticness
    .9, #instrumentalness
    .1, #liveness
    1.5, #valence
    2.5, #tempo
    1 #duration ms
]

# data = dataset
# 
# dataset["popularity"] = dataset["popularity"].apply(lambda pop: pop/100)
# dataset["tempo"] = dataset["tempo"].apply(lambda tpo: tpo/100)
# dataset["loudness"] = dataset["loudness"].apply(lambda ldn: ldn/40)

song_similarity_dict = {}

def calc_similarity_ratings(data):
        accuracy_score = 0
        intersection = False
        popularity_thresh = False
        for col_idx in range(len(predicted_cols)):
            if predicted_cols[col_idx] not in ignore_cols:
                # need to figure out how to do this for best results
                if (y_pred[0][col_idx] > .5 and data[predicted_cols[col_idx]][i] > .5) or (y_pred[0][col_idx] < .5 and data[predicted_cols[col_idx]][i] < .5):
                    accuracy_score += abs(y_pred[0][col_idx] - data[predicted_cols[col_idx]][i]) * prediction_weighting[col_idx]
                else:
                    accuracy_score += abs(pow(y_pred[0][col_idx] - data[predicted_cols[col_idx]][i], 2)) * prediction_weighting[col_idx]
        for genre in data["genres"][i]:
            for comparison_genre in comparison_cats: 
                if fuzz.token_set_ratio(genre, comparison_genre) >= 50:
                    intersection = True      
        if not intersection:
            accuracy_score += 0
        if data["popularity"][i] > y_pred[0][predicted_cols.index("popularity")] - 10:
            popularity_thresh = True
        song_artists = data["artist"][i]
        song_id = data["id"]
        return accuracy_score, intersection, popularity_thresh, song_artists, song_id

for i in range(len(data["songname"])):
    if data["songname"][i] not in song_similarity_dict.keys():
        accuracy_score, intersection, popularity_thresh, song_artists, song_id = calc_similarity_ratings(data)
        song_similarity_dict[data["songname"][i]] = {"accuracy" : accuracy_score, "intersection" : intersection, "popularity" : popularity_thresh, "artists" : song_artists, "id": song_id, "data_idx" : i}

# %%
def get_closest_song(drop_score):
    best_score = 10000
    best_song_name = ""
    best_artists_name = ""
    
    for songname in song_similarity_dict.keys():
        
        song = song_similarity_dict[songname]

        if song["accuracy"] < best_score and songname not in best_names and song["popularity"] - 10:
            best_score = song["accuracy"]
            best_song_name = songname
            best_artists_name = song["artists"]
            best_id = song['id']
        
    if best_score >= drop_score:
        return "DROP", "DROP"
    else:
        return best_song_name, best_artists_name, best_id

# %%
from src.python_files.spotify_helper import get_recs
from src.python_files.record import get_spotify_audio_features

drop_score = 1
playlist_length = 50

best_names = []
best_artists = []
best_ids = []

top_song, top_artist, best_id = get_closest_song(drop_score)

# if top_song != "DROP":
#     recs = get_recs(top_song, top_artist)
#     rec_data = []
#     for rec in recs:
#         print(get_spotify_audio_features({"playback" : rec}))
    
"""
    danceability
energy
speechiness
acousticness
instrumentalness
liveness
valence
tempo
"""
    

for x in range(playlist_length):
    best_song_name, best_artists_name, best_id = get_closest_song(drop_score)
    
    if best_song_name == "DROP":
        break
    
    # print(best_song_name + " score: " + str(best_score) + " by " + song_similarity_dict[best_song_name]["artists"])

    best_names.append(best_song_name)
    best_artists.append(song_similarity_dict[best_song_name]["artists"])
    best_ids.append(best_id)

print(comparison_cats)
print(best_names)
# print(best_artists)
# Out:
# ['bedroom pop', 'indie pop', 'modern rock', 'pop', 'pov: indie']
# ['Cariño', "I've Been In Love", "I Love You I'm Sorry", 'Passionfruit', 'Worth It.', 'Far Away', 'Hush - Still Woozy Remix', 'Risk', 'Reflections', 'The Bird Song', 'You (feat. Travis Scott)', 'Rollerblades', 'Tu Corazón Es Mío...', 'Motion Sickness', 'Tadow', 'Rare', 'Mirage', 'Underdressed at the Symphony', 'Water Flow', 'Perhaps Something More', 'Close The Door', 'Dead Weight', 'Jet Fuel', 'Otro Atardecer', 'Musta Been a Ghost', 'FAMJAM4000', 'La Cienega', 'lowkey', 'Pure', 'Time', 'Paranoia', 'Everybody Wants To Rule The World', 'CHIHIRO', 'Real Life', 'ilomilo', 'Everywhere - 2017 Remaster', 'Amoeba', 'Leftovers', 'Yes yes it is', 'Roommates', 'Cigarettes out the Window', 'Lost but Seeking', "Let's Stay Together", 'Garden Kisses', 'Where Are You Going', 'Drown', 'People Watching', 'C U Girl', 'I miss you I’m sorry', 'In My Life - Remastered 2009']

# %%
import os
from dotenv import load_dotenv
from src.python_files.spotify_helper import update_playlist

load_dotenv()

best_ids = pd.Series(best_ids[0]).fillna("")

playlist_id = os.getenv('PLAYLIST_ID')
update_playlist(best_names, best_artists, playlist_id, best_ids)

# update_playlist(best_names, best_artists)

# %%
from tabulate import tabulate

RED = "\033[91m"
GREEN = "\033[92m"
RESET = "\033[0m"

pred_act = [["track", "accuracy"], ["", "0"]]

for col_idx in range(len(predicted_cols)):
    if predicted_cols[col_idx] not in ignore_cols:
        pred_act[0].append(predicted_cols[col_idx])
        pred_act[1].append(str(round(y_pred[0][col_idx], 3)))
    
outlier_dist = .07
    
for name in best_names:
    r = song_similarity_dict[name]["data_idx"]
    temp_arr = [round(song_similarity_dict[name]["accuracy"], 3)]
    for c in predicted_cols:
        if c not in ignore_cols:
            cr_data = data[c][r]
            if abs(float(pred_act[1][len(temp_arr) + 1]) - cr_data) < outlier_dist:
                temp_arr.append(str(data[c][r]))
            elif float(pred_act[1][len(temp_arr) + 1]) - cr_data > outlier_dist:
                temp_arr.append(RED + str(data[c][r]) + RESET)
            else:
                temp_arr.append(GREEN + str(data[c][r]) + RESET)
    temp_arr.insert(0, name[:20])
    pred_act.append(temp_arr)
        
print(tabulate(pred_act, headers='firstrow', tablefmt='plain'))
# Out:
# track                   accuracy    danceability    energy    speechiness    acousticness    instrumentalness    liveness    valence    tempo
#                            0               0.626     0.552         0.065           0.386             0.287         0.203       0.351  1.133
# Cariño                     0.47            0.646     0.47          0.0284          0.4               0.0348        0.11        0.651  1.13995
# I've Been In Love          0.562           0.679     0.506         0.0671          0.421             0.00216       0.434       0.588  1.14967
# I Love You I'm Sorry       0.579           0.53      0.406         0.033           0.656             0             0.133       0.338  1.1594
# Passionfruit               0.58            0.809     0.463         0.0396          0.256             0.085         0.109       0.364  1.1198
# Worth It.                  0.586           0.736     0.483         0.0682          0.505             1.39e-05      0.351       0.606  1.09932
# Far Away                   0.634           0.669     0.385         0.0277          0.572             0.925         0.111       0.375  1.16045
# Hush - Still Woozy R       0.662           0.708     0.554         0.0311          0.403             0.0428        0.126       0.564  1.03999
# Risk                       0.665           0.727     0.491         0.0592          0.498             0             0.133       0.471  1.13027
# Reflections                0.666           0.648     0.594         0.0293          0.114             0.0462        0.116       0.544  1.13983
# The Bird Song              0.667           0.453     0.546         0.0469          0.767             0             0.0814      0.654  1.16053
# You (feat. Travis Sc       0.669           0.782     0.528         0.0532          0.409             7.89e-05      0.0999      0.389  1.17977
# Rollerblades               0.671           0.566     0.448         0.0799          0.54              7.22e-05      0.0956      0.199  1.10802
# Tu Corazón Es Mío...       0.687           0.696     0.57          0.0289          0.321             1.44e-05      0.15        0.385  1.06032
# Motion Sickness            0.697           0.651     0.546         0.0357          0.774             0.0437        0.0842      0.623  1.07021
# Tadow                      0.698           0.704     0.487         0.0604          0.669             8.64e-05      0.111       0.313  1.21726
# Rare                       0.703           0.719     0.482         0.0423          0.271             0.401         0.0655      0.71   1.19961
# Mirage                     0.705           0.683     0.468         0.0743          0.87              0.673         0.108       0.47   1.17095
# Underdressed at the        0.707           0.598     0.372         0.0274          0.479             6.54e-06      0.116       0.432  1.1802
# Water Flow                 0.71            0.781     0.426         0.0322          0.592             0.571         0.109       0.237  1.04981
# Perhaps Something Mo       0.71            0.754     0.58          0.0386          0.454             0.946         0.101       0.356  1.15006
# Close The Door             0.714           0.617     0.51          0.0289          0.64              0.000266      0.116       0.705  1.16952
# Dead Weight                0.724           0.643     0.492         0.0387          0.181             0.033         0.798       0.601  1.07954
# Jet Fuel                   0.736           0.791     0.557         0.0698          0.54              0             0.103       0.284  1.19973
# Otro Atardecer             0.74            0.777     0.595         0.0375          0.59              0.00139       0.0669      0.546  1.0802
# Musta Been a Ghost         0.747           0.835     0.546         0.0717          0.599             0             0.0752      0.542  1.07013
# FAMJAM4000                 0.749           0.871     0.57          0.0676          0.434             0.452         0.145       0.711  1.16563
# La Cienega                 0.755           0.61      0.319         0.147           0.503             0.000632      0.102       0.217  1.09491
# lowkey                     0.756           0.752     0.494         0.056           0.432             0             0.0869      0.226  1.17901
# Pure                       0.761           0.549     0.426         0.0887          0.703             6.65e-05      0.109       0.212  1.16032
# Time                       0.767           0.849     0.431         0.0542          0.444             0.888         0.116       0.528  1.1013
# Paranoia                   0.768           0.688     0.639         0.0299          0.441             0.5           0.0753      0.773  1.20039
# Everybody Wants To R       0.777           0.645     0.795         0.0527          0.347             0.00389       0.104       0.535  1.12067
# CHIHIRO                    0.779           0.7       0.425         0.0529          0.144             0.879         0.083       0.521  1.10015
# Real Life                  0.78            0.783     0.603         0.0265          0.521             0.351         0.119       0.633  1.00994
# ilomilo                    0.781           0.855     0.423         0.0585          0.724             0.469         0.0896      0.572  1.2002
# Everywhere - 2017 Re       0.781           0.73      0.487         0.0303          0.258             0.01          0.0852      0.731  1.14965
# Amoeba                     0.787           0.739     0.491         0.027           0.791             0.0366        0.1         0.707  1.11008
# Leftovers                  0.788           0.81      0.286         0.0471          0.52              0.00023       0.0816      0.443  1.11032
# Yes yes it is              0.789           0.664     0.525         0.0332          0.334             0.00813       0.196       0.127  1.15009
# Roommates                  0.791           0.755     0.292         0.0311          0.619             1.34e-06      0.114       0.437  1.10005
# Cigarettes out the W       0.791           0.625     0.659         0.0337          0.12              0             0.17        0.594  1.13551
# Lost but Seeking           0.793           0.698     0.543         0.107           0.703             0.918         0.103       0.349  1.05058
# Let's Stay Together        0.797           0.756     0.401         0.0526          0.582             0.011         0.0541      0.514  1.01954
# Garden Kisses              0.798           0.478     0.373         0.0317          0.915             6.36e-06      0.128       0.354  1.20129
# Where Are You Going        0.799           0.444     0.583         0.0259          0.5               0.15          0.105       0.258  0.97492
# Drown                      0.799           0.644     0.554         0.049           0.0803            0             0.098       0.53   1.20024
# People Watching            0.808           0.53      0.592         0.0534          0.381             0             0.294       0.544  1.25721
# C U Girl                   0.811           0.414     0.473         0.116           0.663             0.0523        0.128       0.409  1
# I miss you I’m sorry       0.813           0.445     0.455         0.0575          0.731             1.47e-06      0.124       0.151  1.09885
# In My Life - Remaste       0.816           0.688     0.435         0.0323          0.449             0             0.113       0.435  1.03239
